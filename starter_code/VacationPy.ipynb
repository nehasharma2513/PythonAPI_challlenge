# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
from pathlib import Path
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# !pip install hvplot geoviews datashader

import holoviews as hv
hv.extension('bokeh')
# Out:
# Requirement already satisfied: hvplot in c:\users\nehas\anaconda3\lib\site-packages (0.8.4)
# Collecting geoviews
#   Obtaining dependency information for geoviews from https://files.pythonhosted.org/packages/7c/b1/c27b294bc3bfc06d7721082568f53d076918a039864afc656d6d237fe08b/geoviews-1.10.1-py2.py3-none-any.whl.metadata
#   Downloading geoviews-1.10.1-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: datashader in c:\users\nehas\anaconda3\lib\site-packages (0.15.1)
# Requirement already satisfied: bokeh>=1.0.0 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (3.2.1)
# Requirement already satisfied: colorcet>=2 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (3.0.1)
# Requirement already satisfied: holoviews>=1.11.0 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (1.17.0)
# Requirement already satisfied: pandas in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (1.5.3)
# Requirement already satisfied: numpy>=1.15 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (1.24.3)
# Requirement already satisfied: packaging in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (23.0)
# Requirement already satisfied: panel>=0.11.0 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (1.2.1)
# Requirement already satisfied: param>=1.9.0 in c:\users\nehas\anaconda3\lib\site-packages (from hvplot) (1.13.0)
# Collecting cartopy>=0.18.0 (from geoviews)
#   Obtaining dependency information for cartopy>=0.18.0 from https://files.pythonhosted.org/packages/bb/50/ab5495dcc22587179134cd37e6534212babeda78e86bda311c37c773f086/Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting shapely (from geoviews)
#   Downloading shapely-2.0.1-cp311-cp311-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      --------------------------- ------------ 1.0/1.4 MB 20.0 MB/s eta 0:00:01
#      ---------------------------------------- 1.4/1.4 MB 17.4 MB/s eta 0:00:00
# Collecting pyproj (from geoviews)
#   Obtaining dependency information for pyproj from https://files.pythonhosted.org/packages/79/95/eb68113c5b5737c342bde1bab92705dabe69c16299c5a122616e50f1fbd6/pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata
#   Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: xyzservices in c:\users\nehas\anaconda3\lib\site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: dask in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (2023.6.0)
# Requirement already satisfied: datashape in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (0.5.4)
# Requirement already satisfied: numba in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (0.57.0)
# Requirement already satisfied: pillow in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (9.4.0)
# Requirement already satisfied: pyct in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (0.5.0)
# Requirement already satisfied: requests in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (2.31.0)
# Requirement already satisfied: scipy in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (1.10.1)
# Requirement already satisfied: toolz in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (0.12.0)
# Requirement already satisfied: xarray in c:\users\nehas\anaconda3\lib\site-packages (from datashader) (2023.6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\nehas\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (3.1.2)
# Requirement already satisfied: contourpy>=1 in c:\users\nehas\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (1.0.5)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\nehas\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\nehas\anaconda3\lib\site-packages (from bokeh>=1.0.0->hvplot) (6.3.2)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\nehas\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.1)
# Collecting pyshp>=2.1 (from cartopy>=0.18.0->geoviews)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.5 kB ? eta -:--:--
#      ---------------------------------------- 46.5/46.5 kB ? eta 0:00:00
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\nehas\anaconda3\lib\site-packages (from holoviews>=1.11.0->hvplot) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\nehas\anaconda3\lib\site-packages (from pandas->hvplot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\nehas\anaconda3\lib\site-packages (from pandas->hvplot) (2022.7)
# Requirement already satisfied: markdown in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (3.4.1)
# Requirement already satisfied: markdown-it-py in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.2.0)
# Requirement already satisfied: linkify-it-py in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (0.3.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.65.0)
# Requirement already satisfied: bleach in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.1.0)
# Requirement already satisfied: typing-extensions in c:\users\nehas\anaconda3\lib\site-packages (from panel>=0.11.0->hvplot) (4.7.1)
# Requirement already satisfied: certifi in c:\users\nehas\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.7.22)
# Requirement already satisfied: click>=8.0 in c:\users\nehas\anaconda3\lib\site-packages (from dask->datashader) (8.0.4)
# Requirement already satisfied: cloudpickle>=1.5.0 in c:\users\nehas\anaconda3\lib\site-packages (from dask->datashader) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\nehas\anaconda3\lib\site-packages (from dask->datashader) (2023.3.0)
# Requirement already satisfied: partd>=1.2.0 in c:\users\nehas\anaconda3\lib\site-packages (from dask->datashader) (1.2.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\nehas\anaconda3\lib\site-packages (from dask->datashader) (6.0.0)
# Requirement already satisfied: multipledispatch>=0.4.7 in c:\users\nehas\anaconda3\lib\site-packages (from datashape->datashader) (0.6.0)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\nehas\anaconda3\lib\site-packages (from numba->datashader) (0.40.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nehas\anaconda3\lib\site-packages (from requests->datashader) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nehas\anaconda3\lib\site-packages (from requests->datashader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nehas\anaconda3\lib\site-packages (from requests->datashader) (1.26.16)
# Requirement already satisfied: colorama in c:\users\nehas\anaconda3\lib\site-packages (from click>=8.0->dask->datashader) (0.4.6)
# Requirement already satisfied: zipp>=0.5 in c:\users\nehas\anaconda3\lib\site-packages (from importlib-metadata>=4.13.0->dask->datashader) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nehas\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: six in c:\users\nehas\anaconda3\lib\site-packages (from multipledispatch>=0.4.7->datashape->datashader) (1.16.0)
# Requirement already satisfied: locket in c:\users\nehas\anaconda3\lib\site-packages (from partd>=1.2.0->dask->datashader) (1.0.0)
# Requirement already satisfied: webencodings in c:\users\nehas\anaconda3\lib\site-packages (from bleach->panel>=0.11.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in c:\users\nehas\anaconda3\lib\site-packages (from linkify-it-py->panel>=0.11.0->hvplot) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\nehas\anaconda3\lib\site-packages (from markdown-it-py->panel>=0.11.0->hvplot) (0.1.0)
# Downloading geoviews-1.10.1-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.8 kB ? eta -:--:--
#    --------------------------------------- 509.8/509.8 kB 16.1 MB/s eta 0:00:00
# Downloading Cartopy-0.22.0-cp311-cp311-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ----- ---------------------------------- 1.6/11.2 MB 51.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/11.2 MB 35.8 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.2 MB 35.1 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.2 MB 32.3 MB/s eta 0:00:01
#    -------------------------- ------------- 7.3/11.2 MB 33.6 MB/s eta 0:00:01
#    --------------------------- ------------ 7.7/11.2 MB 30.6 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.2 MB 30.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.2 MB 29.1 MB/s eta 0:00:01
#    -------------------------------------- - 10.9/11.2 MB 28.4 MB/s eta 0:00:01
#    ---------------------------------------  11.2/11.2 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 24.2 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp311-cp311-win_amd64.whl (6.1 MB)
#    ---------------------------------------- 0.0/6.1 MB ? eta -:--:--
#    ------ --------------------------------- 1.1/6.1 MB 33.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.0/6.1 MB 25.9 MB/s eta 0:00:01
#    ------------------ --------------------- 2.9/6.1 MB 22.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.1 MB 21.1 MB/s eta 0:00:01
#    ------------------------------ --------- 4.6/6.1 MB 20.9 MB/s eta 0:00:01
#    ------------------------------------ --- 5.5/6.1 MB 20.7 MB/s eta 0:00:01
#    ---------------------------------------  6.1/6.1 MB 20.4 MB/s eta 0:00:01
#    ---------------------------------------- 6.1/6.1 MB 18.5 MB/s eta 0:00:00
# Installing collected packages: shapely, pyshp, pyproj, cartopy, geoviews
# Successfully installed cartopy-0.22.0 geoviews-1.10.1 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.1
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# !pip install ipympl
# Out:
# Collecting ipympl
#   Downloading ipympl-0.9.3-py2.py3-none-any.whl (511 kB)
#      ---------------------------------------- 0.0/511.6 kB ? eta -:--:--
#      ------------------------------------- 511.6/511.6 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: ipython<9 in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (8.12.0)
# Requirement already satisfied: numpy in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (1.24.3)
# Requirement already satisfied: ipython-genutils in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (9.4.0)
# Requirement already satisfied: traitlets<6 in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (5.7.1)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (8.0.4)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipympl) (3.7.1)
# Requirement already satisfied: backcall in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: colorama in c:\users\nehas\anaconda3\lib\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\nehas\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (6.19.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\nehas\anaconda3\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: comm>=0.1.1 in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (7.4.9)
# Requirement already satisfied: nest-asyncio in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (1.5.6)
# Requirement already satisfied: psutil in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\nehas\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\nehas\anaconda3\lib\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\nehas\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.5)
# Requirement already satisfied: six>=1.5 in c:\users\nehas\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing in c:\users\nehas\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\nehas\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\nehas\anaconda3\lib\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Requirement already satisfied: entrypoints in c:\users\nehas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\nehas\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (5.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\nehas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\nehas\anaconda3\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<9,>=7.6.0->ipympl) (305.1)
# Installing collected packages: ipympl
# Successfully installed ipympl-0.9.3

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   papatowai -46.5619  169.4708      5.86        92         100
# 1        1  whitehorse  60.7161 -135.0538      7.43        77          40
# 2        2       utrik  11.2278  169.8474     28.67        78          92
# 3        3     sarikei   2.1167  111.5167     30.61        52          79
# 4        4   boa vista   2.8197  -60.6733     29.99        58           0
#
#    Wind Speed Country        Date
# 0       12.38      NZ  1696218697
# 1        4.63      CA  1696218697
# 2        5.84      MH  1696218697
# 3        0.99      MY  1696218697
# 4        2.57      BR  1696218698

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
hv.extension('bokeh')
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 900,
    size = "Humidity",
    scale = 0.7,
    color="City"
)
map_plot_1



# Display the map
map_plot_1
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df_clean = city_data_df[(city_data_df['Max Temp'] < 27) & 
                                  (city_data_df['Max Temp'] > 21) & 
                                  (city_data_df['Wind Speed'] < 4.5) &
                                   (city_data_df['Cloudiness'] == 0)]


# Drop any rows with null values
city_data_df_clean = city_data_df.dropna()

# Display sample data
city_data_df_clean.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0   papatowai -46.5619  169.4708      5.86        92         100
# 1        1  whitehorse  60.7161 -135.0538      7.43        77          40
# 2        2       utrik  11.2278  169.8474     28.67        78          92
# 3        3     sarikei   2.1167  111.5167     30.61        52          79
# 4        4   boa vista   2.8197  -60.6733     29.99        58           0
#
#    Wind Speed Country        Date
# 0       12.38      NZ  1696218697
# 1        4.63      CA  1696218697
# 2        5.84      MH  1696218697
# 3        0.99      MY  1696218697
# 4        2.57      BR  1696218698

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=city_data_df_clean[['City', 'Country', 'Lat', 'Lng', 'Humidity']]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']=''

# Display sample data
hotel_df.head()
# Out:
# C:\Users\nehas\AppData\Local\Temp\ipykernel_7476\4183029231.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name']=''
#          City Country      Lat       Lng  Humidity Hotel Name
# 0   papatowai      NZ -46.5619  169.4708        92
# 1  whitehorse      CA  60.7161 -135.0538        77
# 2       utrik      MH  11.2278  169.8474        78
# 3     sarikei      MY   2.1167  111.5167        52
# 4   boa vista      BR   2.8197  -60.6733        58

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
   "apiKey":geoapify_key,
    "categories":"accommodation.hotel",
    "limit":20
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude=row['Lat']
    longitude=row['Lng']
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")
    
# Display sample data
hotel_df
# Out:
# Starting hotel search
# papatowai - nearest hotel: No hotel found
# whitehorse - nearest hotel: Town & Mountain Hotel
# utrik - nearest hotel: No hotel found
# sarikei - nearest hotel: No hotel found
# boa vista - nearest hotel: Aipana Plaza Hotel
# smirnykh - nearest hotel: No hotel found
# klyuchi - nearest hotel: No hotel found
# tsetserleg - nearest hotel: Буян зочид буудал
# chabahar - nearest hotel: هتل سپیده
# waitangi - nearest hotel: Hotel Chathams
# port-aux-francais - nearest hotel: Keravel
# anadyr - nearest hotel: Гостевой дом
# okha - nearest hotel: Сфера
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
# edinburgh of the seven seas - nearest hotel: No hotel found
# keflavik - nearest hotel: Núpan Deluxe
# vorgashor - nearest hotel: София
# shantou - nearest hotel: 金海湾大酒店
# banda aceh - nearest hotel: Hotel 61
# adamstown - nearest hotel: No hotel found
# cotonou - nearest hotel: BENIN ROYAL HOTEL
# magadan - nearest hotel: Гостиница «ВМ-Центр»
# barranca - nearest hotel: Emperador
# ust-nera - nearest hotel: гостиница "Солнечная"
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# grytviken - nearest hotel: No hotel found
# polyarnyy - nearest hotel: No hotel found
# punta arenas - nearest hotel: Hotel Lacolet
# montepuez - nearest hotel: Complexo Messalo
# sao miguel do araguaia - nearest hotel: Hotel São Miguel
# isangel - nearest hotel: Tanna Lodge
# albany - nearest hotel: No hotel found
# saumur - nearest hotel: ECOLODGE DE LOIRE
# yuzhno-kurilsk - nearest hotel: Dom Druzhby
# port mathurin - nearest hotel: Escale Vacances
# thinadhoo - nearest hotel: No hotel found
# bredasdorp - nearest hotel: Victoria Hotel
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# lebu - nearest hotel: No hotel found
# aasiaat - nearest hotel: SØMA
# port elizabeth - nearest hotel: Waterford Hotel
# kalmunai - nearest hotel: Saji new food
# vilyuchinsk - nearest hotel: Победа
# murakami - nearest hotel: 扇屋旅館
# bethel - nearest hotel: Hampton Inn Danbury
# yellowknife - nearest hotel: No hotel found
# beichengqu - nearest hotel: 春江大酒店
# suixi - nearest hotel: No hotel found
# pasni - nearest hotel: Juddi Hotel
# hawaiian paradise park - nearest hotel: No hotel found
# bilibino - nearest hotel: No hotel found
# al mijlad - nearest hotel: No hotel found
# mandalgovi - nearest hotel: АЛТАНГОВЬ Hotel
# hermanus - nearest hotel: Aloe guest house
# gadzhiyevo - nearest hotel: Оазис
# jamestown - nearest hotel: DoubleTree Jamestown
# georgetown - nearest hotel: Page 63 hostel
# ancud - nearest hotel: Cabañas
# atafu village - nearest hotel: No hotel found
# chimbote - nearest hotel: Hostal Diamante Chimbote
# tura - nearest hotel: No hotel found
# cedeira - nearest hotel: Hospedería Casa Cordobelas
# eyl - nearest hotel: فندق ايل دابي
# sur - nearest hotel: Sur Hotel
# jalapa - nearest hotel: Casa de Juan
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# kodiak - nearest hotel: Shelikof Lodge
# vadso - nearest hotel: Scandic Vadsø
# ironwood - nearest hotel: Comfort Inn
# turtas - nearest hotel: Сибирь
# iqaluit - nearest hotel: Frobisher Inn
# nuuk - nearest hotel: Nordbo
# tvoroyri - nearest hotel: Hotel Tvøroyri
# aral - nearest hotel: No hotel found
# constantia - nearest hotel: Hotel Chérica
# sitka - nearest hotel: Aspen Suites Hotel
# saint-leu - nearest hotel: Iloha Seaview Hôtel
# stanley - nearest hotel: Hotel 52
# tralee - nearest hotel: The Ashe Hotel
# badger - nearest hotel: Hotel North Pole
# west island - nearest hotel: Cocos Village Bungalows
# akureyri - nearest hotel: Hótel Norðurland
# geraldton - nearest hotel: Ocean Centre Hotel
# lihue - nearest hotel: Kauai Palms
# umm kaddadah - nearest hotel: No hotel found
# vorkuta - nearest hotel: "Мегаполис"
# borogontsy - nearest hotel: No hotel found
# dawei - nearest hotel: Royal Dawei ဟိုတယ်
# bassar - nearest hotel: Hôtel Bassar
# prado - nearest hotel: Pousada Recanto do Prado
# gebeit - nearest hotel: No hotel found
# margaret river - nearest hotel: Margaret River Hotel
# arteche - nearest hotel: No hotel found
# midvagur - nearest hotel: Hotel Vágar
# blackmans bay - nearest hotel: Villa Howden
# longyearbyen - nearest hotel: The Vault
# zakynthos - nearest hotel: Phoenix Hotel
# labrador city - nearest hotel: Carol Inn
# tarauaca - nearest hotel: Hotel Estrela
# mirpur khas - nearest hotel: Cafe Sharif Dosti Hotel
# thompson - nearest hotel: Thompson Inn
# zhenlai - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: Complexe Belova
# paratinga - nearest hotel: No hotel found
# ingeniero jacobacci - nearest hotel: Gran Hotel Argentino
# tiksi - nearest hotel: Арктика
# malango - nearest hotel: Madarana
# boca do acre - nearest hotel: No hotel found
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# touros - nearest hotel: Pousada Atlântico
# salym - nearest hotel: Каравани
# tazacorte - nearest hotel: App Leyma
# olonkinbyen - nearest hotel: No hotel found
# hilo - nearest hotel: Dolphin Bay Hotel
# iskateley - nearest hotel: Авантаж
# isafjordur - nearest hotel: Hótel Horn
# mbandjok - nearest hotel: No hotel found
# lagoa - nearest hotel: Casa da Madrinha
# invercargill - nearest hotel: The Grand
# udachny - nearest hotel: Вилюй
# shimoda - nearest hotel: ホテルウラガ
# wladyslawowo - nearest hotel: Titanic
# ha'il - nearest hotel: فندق كلاسيك
# san jeronimo de juarez - nearest hotel: No hotel found
# moultrie - nearest hotel: Hampton
# takoradi - nearest hotel: Hillcrest
# xinyang - nearest hotel: 德龙太子酒店
# crane - nearest hotel: No hotel found
# san javier - nearest hotel: Mar Mediterráneo
# katsuura - nearest hotel: 潮騒の宿
# avarua - nearest hotel: Paradise Inn
# coquimbo - nearest hotel: Hotel Iberia
# noosa heads - nearest hotel: Costa Nova Apartments
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# rio claro - nearest hotel: Hotel Premier
# fisterra - nearest hotel: Hotel Temático do Banco Azul
# muroto-misakicho - nearest hotel: 民宿うらしま
# ta`u - nearest hotel: No hotel found
# mana - nearest hotel: Le Samana
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# weno - nearest hotel: High Tide Hotel
# nadym - nearest hotel: Янтарная
# shorkot - nearest hotel: Paradise Hotel
# happy valley-goose bay - nearest hotel: Hotel North Two
# freeport - nearest hotel: The Freeport Inn and Marina
# port augusta - nearest hotel: Hotel Commonwealth
# taitung city - nearest hotel: 瑞軒民宿
# afaahiti - nearest hotel: Omati Lodge
# kapuskasing - nearest hotel: Travelodge
# saint-joseph - nearest hotel: PALM Hotel & Spa
# jinghong - nearest hotel: โรงแรมสืเบา
# san patricio - nearest hotel: No hotel found
# bardai - nearest hotel: No hotel found
# seminole - nearest hotel: Best Western Plus Sanford
# port alfred - nearest hotel: No hotel found
# choibalsan - nearest hotel: Зүүн Ордон Зочид Буудал
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# tyumen - nearest hotel: На Каширской
# cabo san lucas - nearest hotel: Comfort Rooms
# eydhafushi - nearest hotel: The Westin Maldives Miriandhoo Resort
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# mbanza-ngungu - nearest hotel: auberge la rose
# tucuma - nearest hotel: No hotel found
# nagqu - nearest hotel: Naqu Hotel
# pesqueira - nearest hotel: Hotel Estação Cruzeiro
# ulsan - nearest hotel: Shilla Stay Ulsan
# hami - nearest hotel: Хами
# labytnangi - nearest hotel: Семь лиственниц
# urangan - nearest hotel: Ramada
# ghormach - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# talnakh - nearest hotel: Талнах
# muang khong - nearest hotel: Bundavong
# necocli - nearest hotel: Casa Hotel Necoclí
# huatabampo - nearest hotel: No hotel found
# kingston - nearest hotel: Aphrodite Hotel
# cururupu - nearest hotel: No hotel found
# omutninsk - nearest hotel: гостиница "Центральная"
# bahir dar - nearest hotel: ናኪ ሆቴል
# pemangkat - nearest hotel: Hotel Kelapa Gading
# montalvo - nearest hotel: No hotel found
# bam - nearest hotel: هتل جهانگردی بم
# zouerate - nearest hotel: فندق تيرس زمور
# selfoss - nearest hotel: Miðgarður
# mejit - nearest hotel: No hotel found
# xinyuan - nearest hotel: No hotel found
# niamey - nearest hotel: Redidence Croix du Sud
# ola - nearest hotel: No hotel found
# cockburn town - nearest hotel: The Salt Raker Inn
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# piacabucu - nearest hotel: O Leão
# portland - nearest hotel: the Hoxton
# inari - nearest hotel: Villa Lanca
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# dalandzadgad - nearest hotel: Хан Уул буудал
# rostovka - nearest hotel: No hotel found
# ribeira grande - nearest hotel: Hospedaria JSF
# pastavy - nearest hotel: Паставы
# kargasok - nearest hotel: Титан
# susuman - nearest hotel: No hotel found
# ilhabela - nearest hotel: Vila Kebaya
# baidoa - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# honefoss - nearest hotel: Comfort Hotel Ringerike
# ust'-ilimsk - nearest hotel: Усть-Илимск
# shingu - nearest hotel: ホテルニューパレス
# akjoujt - nearest hotel: فندق فاطمة
# dukhan - nearest hotel: No hotel found
# pitanga - nearest hotel: No hotel found
# val-d'or - nearest hotel: Quality Inn & Suites
# saacow - nearest hotel: No hotel found
# tofol - nearest hotel: Nautilus Resort
# diawara - nearest hotel: No hotel found
# san ignacio rio muerto - nearest hotel: No hotel found
# gorontalo - nearest hotel: Grand City Hotel
# khash - nearest hotel: No hotel found
# fandriana - nearest hotel: Hotel Sariaka
# colonia - nearest hotel: Wasserturm Hotel Cologne
# taksimo - nearest hotel: No hotel found
# banska bystrica - nearest hotel: Motel Duvoks
# lepsy - nearest hotel: Orley
# ambodifotatra - nearest hotel: Les Palmiers
# presidente medici - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# barakani - nearest hotel: Al Amal
# tolanaro - nearest hotel: Hôtel Mahavokey
# axim - nearest hotel: Axim Beach Hotel
# colac - nearest hotel: No hotel found
# roma - nearest hotel: Wingate by Wyndham Rome
# inyati - nearest hotel: No hotel found
# porto - nearest hotel: Hotel Vera Cruz
# pailon - nearest hotel: No hotel found
# sesheke - nearest hotel: Sisheke Lodge
# port lincoln - nearest hotel: Boston Hotel
# dori - nearest hotel: Kuin Deni Dori
# lai - nearest hotel: Auberge Shalom de Laï
# parscov - nearest hotel: Hotel Măgura ***
# sumenep - nearest hotel: No hotel found
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# ad dabbah - nearest hotel: No hotel found
# santa cruz - nearest hotel: Aviador Hotel Boutique
# howrah - nearest hotel: Sun India Guest House
# roja - nearest hotel: Roja
# namibe - nearest hotel: Hotel Chik Chik Namibe
# ipueiras - nearest hotel: Pousada Residência
# korla - nearest hotel: Silver Star Hotel
# antofagasta - nearest hotel: Hotel Colón
# chayan - nearest hotel: No hotel found
# punta del este - nearest hotel: Hotel Aquarium
# tenno - nearest hotel: 男鹿の屋
# tabou - nearest hotel: hôtel le rochet
# la passe - nearest hotel: L'Estuaire
# la maddalena - nearest hotel: Hotel Excelsior
# qaqortoq - nearest hotel: Hotel Qaqortoq
# guerrero negro - nearest hotel: Plaza sal paraiso
# lorengau - nearest hotel: Seeadler Bay Hotel
# lautoka - nearest hotel: Cathay Hotel
# caister-on-sea - nearest hotel: Premier Inn
# codrington - nearest hotel: No hotel found
# ketchikan - nearest hotel: Cape Fox Lodge
# flin flon - nearest hotel: Copperbelt Hotel
# pathein - nearest hotel: Taan Taan Ta
# myitkyina - nearest hotel: New Light Hotel
# smithers - nearest hotel: Sunshine Inn Hotel
# yur'yevets - nearest hotel: Гостиница "Юрьевец"
# sint michiel liber - nearest hotel: Blue Bay Lodges
# arenapolis - nearest hotel: No hotel found
# callao - nearest hotel: Casa Ronald
# kilindoni - nearest hotel: Ibizza Inn
# usak - nearest hotel: No hotel found
# pauini - nearest hotel: No hotel found
# colares - nearest hotel: Hotel Arribas
# linxia chengguanzhen - nearest hotel: 如家酒店
# fale old settlement - nearest hotel: No hotel found
# enewetak - nearest hotel: No hotel found
# dwarka - nearest hotel: The Dwarika Hotel
# tallulah - nearest hotel: No hotel found
# bikenibeu village - nearest hotel: Otintaai Hotel
# ithaca - nearest hotel: Hilton Garden Inn
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# remiremont - nearest hotel: Hôtel du Cheval de Bronze
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# laguna - nearest hotel: Holiday Inn Express & Suites
# caibarien - nearest hotel: Restaurante Hostal El Coliseo
# kirensk - nearest hotel: Ивушка
# novofedorivka - nearest hotel: Оазис
# luganville - nearest hotel: Beachfront Resort
# bazarak - nearest hotel: No hotel found
# novyy chirkey - nearest hotel: No hotel found
# chibougamau - nearest hotel: No hotel found
# palmer - nearest hotel: No hotel found
# sao felix do xingu - nearest hotel: Hotel Terraço
# usogorsk - nearest hotel: Единственная
# la tuque - nearest hotel: Auberge La Résidence
# fort wellington - nearest hotel: No hotel found
# woods creek - nearest hotel: Best Western Sky Valley Inn
# juneau - nearest hotel: Ramada by Wyndham Juneau
# tual - nearest hotel: Suita
# manismata - nearest hotel: No hotel found
# yuza - nearest hotel: 後藤屋旅館
# revda - nearest hotel: Металлург
# al bawiti - nearest hotel: Old Oasis Hotel
# la paz - nearest hotel: Alojamiento Tokio
# umarkot - nearest hotel: No hotel found
# kapit - nearest hotel: Haip
# bandundu - nearest hotel: Majestik Hotel
# ostersund - nearest hotel: Hotell Stortorget
# bamboo flat - nearest hotel: Hotel Megapode Nest
# hasaki - nearest hotel: 大新旅館
# sao gabriel da cachoeira - nearest hotel: Hotel Deus Me Deu
# el porvenir - nearest hotel: No hotel found
# al jawf - nearest hotel: No hotel found
# lompoc - nearest hotel: Embassy Suites by Hilton Lompoc Central Coast
# narrabri - nearest hotel: Tattersall's Hotel
# acapulco de juarez - nearest hotel: Hotel del Valle
# kone - nearest hotel: Pacifik Appartels
# charters towers - nearest hotel: No hotel found
# corabia - nearest hotel: Pericle Bar and Hostel
# sinabang - nearest hotel: No hotel found
# soio - nearest hotel: Hotel Maria Teres
# chauk - nearest hotel: Royal Chauk
# undurkhaan - nearest hotel: Khanburged Hotel
# east london - nearest hotel: No hotel found
# altay - nearest hotel: Sunshine Holiday Hotel
# flying fish cove - nearest hotel: Christmas Island Lodge
# pierre - nearest hotel: Quality Inn
# cidreira - nearest hotel: Hotel Castelo
# kovernino - nearest hotel: No hotel found
# nova sintra - nearest hotel: Residência Ka Dencho
# arraial do cabo - nearest hotel: No hotel found
# san pedro pochutla - nearest hotel: Olimpia
# 'ain el melh - nearest hotel: No hotel found
# yelizovo - nearest hotel: Николина Усадьба
# beau vallon - nearest hotel: Le Jardin de Beau Vallon
# boende - nearest hotel: Hotel Reference
# hede - nearest hotel: No hotel found
# natal - nearest hotel: Natal Palace Hotel
# savino - nearest hotel: No hotel found
# nova xavantina - nearest hotel: Hotel Morada do Sol
# talcahuano - nearest hotel: Club Recreativo Armada de Chile
# holualoa - nearest hotel: Kona Hotel
# palangkaraya - nearest hotel: Swiss-Belhotel
# lagunas - nearest hotel: Hospedaje Eco
# queenstown - nearest hotel: Queens Hotel
# island harbour - nearest hotel: Premier Inn
# borgarnes - nearest hotel: Borgarnes
# st. john's - nearest hotel: Alt Hotel
# praia da vitoria - nearest hotel: Salles
# rongelap - nearest hotel: No hotel found
# nguigmi - nearest hotel: Guest PAM
# puerto baquerizo moreno - nearest hotel: Dory's House
# tocopilla - nearest hotel: hotel Isidora
# arbatache - nearest hotel: Hôtel Eddounia
# robertsport - nearest hotel: Nana's Lodge
# broken hill - nearest hotel: Ibis Styles
# kotovo - nearest hotel: Тамара гостиничный комплекс
# la ronge - nearest hotel: La Ronge Hotel and Suites
# springs - nearest hotel: Manhattan Hotel & Action Bar
# ugoofaaru - nearest hotel: No hotel found
# aleg - nearest hotel: Hotel Oasis Aleg
# pacific grove - nearest hotel: Pacific Grove Inn
# wurno - nearest hotel: No hotel found
# trincomalee - nearest hotel: Summer set inn
# ain temouchent - nearest hotel: Hôtel Restaurant Zeidour
# ziniare - nearest hotel: Residence Les Saints Innocents
# okhotsk - nearest hotel: No hotel found
# citra - nearest hotel: Orange Blossom Motel & RV Park
# dzhetygara - nearest hotel: гостиница "Октябрь"
# kirakira - nearest hotel: No hotel found
# hadibu - nearest hotel: No hotel found
# kuragino - nearest hotel: No hotel found
# la gomera - nearest hotel: No hotel found
# taro - nearest hotel: Padma Resort Ubud
# new norfolk - nearest hotel: Woodbridge on the Derwent
# kimberley - nearest hotel: Royal Paume Hotel
# tongchuanshi - nearest hotel: No hotel found
# kohlu - nearest hotel: No hotel found
# yasnogorsk - nearest hotel: No hotel found
# wagar - nearest hotel: No hotel found
# san antonio de pale - nearest hotel: No hotel found
# chonchi - nearest hotel: Hotel Huildín
# jouy-en-josas - nearest hotel: Bâtiment X
# khandyga - nearest hotel: Апельсин
# susangerd - nearest hotel: No hotel found
# umba - nearest hotel: Гостиница
# ryotsu-minato - nearest hotel: ゆたかや旅館
# atherton - nearest hotel: Britannia Hotel
# carnarvon - nearest hotel: No hotel found
# guarapari - nearest hotel: Osmar Hotel
# dzhangala - nearest hotel: Общежитие Жангалинского ЛПУ
# port saint john's - nearest hotel: Outback Inn
# as sulayyil - nearest hotel: No hotel found
# taltal - nearest hotel: Hostería Taltal
# badagry - nearest hotel: Kappo Hotel
# twon-brass - nearest hotel: KC Hotel
# blackwater - nearest hotel: No hotel found
# taiyuan - nearest hotel: 汾酒大厦
# kutoarjo - nearest hotel: Hotel Kencana
# chukhloma - nearest hotel: Березка
# norfolk county - nearest hotel: Fairfield Inn
# ebon - nearest hotel: No hotel found
# sirvintos - nearest hotel: No hotel found
# uelzen - nearest hotel: Hotel am Hammersteinplatz
# antonio enes - nearest hotel: Hotel Quirimbas
# kolpny - nearest hotel: No hotel found
# agios nikolaos - nearest hotel: No hotel found
# monrovia - nearest hotel: Bella Casa Hotel
# kajiado - nearest hotel: Eastwood Hotel
# uporovo - nearest hotel: No hotel found
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# qamdo - nearest hotel: 银杏商务宾馆
# santiago de veraguas - nearest hotel: Cion Gi
# grande prairie - nearest hotel: Sandman Hotel Grande Prairie
# north branch - nearest hotel: AmericInn
# santa elena de uairen - nearest hotel: Posada Villa Fairmont
# el abiodh sidi cheikh - nearest hotel: No hotel found
# kailua-kona - nearest hotel: Kona Seaside Hotel
# porto cristo - nearest hotel: No hotel found
# aldan - nearest hotel: гостинница Велком Плаза
# galle - nearest hotel: Jungle Hostel Villa
# hirara - nearest hotel: 古謝そば屋
# bukama - nearest hotel: Mission catholique
# changli - nearest hotel: 客房
# labasa - nearest hotel: Grand Eastern Hotel
# saint-denis - nearest hotel: Tribe
# tazovsky - nearest hotel: Тазовчанка
# san julian - nearest hotel: No hotel found
# maebaru-chuo - nearest hotel: HOTEL AZ 福岡糸島店
# ratchaburi - nearest hotel: Chonticha place
# kavaratti - nearest hotel: No hotel found
# upper dir - nearest hotel: PTDC Motel
# leava - nearest hotel: Fia fia
# carauari - nearest hotel: No hotel found
# margate - nearest hotel: The Reading Rooms
# bogale - nearest hotel: No hotel found
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# pionerskiy - nearest hotel: No hotel found
# kidal - nearest hotel: No hotel found
# kolonia town - nearest hotel: Cliff Rainbow Hotel
# freetown - nearest hotel: Formal Leona hotel
# barra de santo antonio - nearest hotel: Resort Fazenda Fiore
# ulundi - nearest hotel: Protea Hotel
# tongliao - nearest hotel: No hotel found
# sao miguel do guama - nearest hotel: No hotel found
# colachel - nearest hotel: No hotel found
# port sudan - nearest hotel: Ranya Hotel
# howard springs - nearest hotel: No hotel found
# san luis de la loma - nearest hotel: No hotel found
# paracuru - nearest hotel: Vento Brasil
# tisul' - nearest hotel: No hotel found
# vedi - nearest hotel: No hotel found
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# saudarkrokur - nearest hotel: Mikligarður
# tarawa - nearest hotel: Betio Lodge
# marsh harbour - nearest hotel: Lofty Fig Villas
# oum hadjer - nearest hotel: No hotel found
# felipe carrillo puerto - nearest hotel: Hotel María José
# rubtsovsk - nearest hotel: Esperanto
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# kedrovyy - nearest hotel: No hotel found
# bubaque - nearest hotel: Chez Julio
# harstad - nearest hotel: Scandic Harstad
# carbonear - nearest hotel: No hotel found
# perryville - nearest hotel: Comfort Inn
# troitsko-pechorsk - nearest hotel: Гостиница "Печора"
# maintirano - nearest hotel: Hotel Safari
# selkirk - nearest hotel: No hotel found
# tonj - nearest hotel: No hotel found
# zhongxiang - nearest hotel: No hotel found
# sarina - nearest hotel: Tandara Hotel
# korfovskiy - nearest hotel: No hotel found
# qulsary - nearest hotel: Камилла
# constitucion - nearest hotel: Hostal Alameda
# kapa'a - nearest hotel: Pono Kai Resort
# villa gesell - nearest hotel: Hotel El Faro
# sola - nearest hotel: No hotel found
# amahai - nearest hotel: Onemay Hotel
# zahedan - nearest hotel: هتل صالح;بانک ملی
# kokpekty - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# chipinge - nearest hotel: No hotel found
# uturoa - nearest hotel: Hawaiki Nui hotel
# bac lieu - nearest hotel: Khách sạn Bạc Liêu
# zaysan - nearest hotel: Рахат қонақүй
# chalisgaon - nearest hotel: No hotel found
# vilyuysk - nearest hotel: Мария
# karratha - nearest hotel: Karratha International Hotel
# serowe - nearest hotel: Tshwaragano Hotel
# tot'ma - nearest hotel: No hotel found
# kaga bandoro - nearest hotel: No hotel found
# bonthe - nearest hotel: No hotel found
# djambala - nearest hotel: No hotel found
# timbuktu - nearest hotel: Hotel La Maison
# enoch - nearest hotel: Travelodge by Wyndham Cedar City
# n'zeto - nearest hotel: No hotel found
# tamanrasset - nearest hotel: فندق الأمان
# suva - nearest hotel: Extension 68
# al muwayh - nearest hotel: فندق ومطعم الموية
# chaiya - nearest hotel: Udomlarp Hotel
# skrunda - nearest hotel: No hotel found
# zeya - nearest hotel: Серебряный створ
# amalapuram - nearest hotel: Homewood Suites
# aktau - nearest hotel: Гульдана
# hargeysa - nearest hotel: No hotel found
# mil'kovo - nearest hotel: Дрозды
# owosso - nearest hotel: Comstock Inn and Convention Center
# fort st. john - nearest hotel: Fort St. John Motor Inn
# shahrak - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# margherita - nearest hotel: Blue Moon Hotel
# california - nearest hotel: Holiday Inn Express
# ponta delgada - nearest hotel: Hotel Talisman
# gamba - nearest hotel: No hotel found
# eppstein - nearest hotel: Zum Taunus
# albertina - nearest hotel: Hotel Parque das Primaveras
# naklo nad notecia - nearest hotel: No hotel found
# azul - nearest hotel: Gran Hotel Azul
# adrar - nearest hotel: No hotel found
# oamaru - nearest hotel: Brydone Hotel Oamaru
# sombrerete - nearest hotel: No hotel found
# altai - nearest hotel: Altai hotel 40000-100000T
# sambava - nearest hotel: Royal Sava Hôtel
# prince george - nearest hotel: Travelodge by Wyndham Prince George
# el calafate - nearest hotel: Hostería Las Avutardas
# karachi - nearest hotel: Quetta Agha Hotel
# salalah - nearest hotel: Muscat International Hotel
# coahuayana de hidalgo - nearest hotel: No hotel found
# hermosillo - nearest hotel: Lucerna
# sonderborg - nearest hotel: Hotel 6400
# makurazaki - nearest hotel: グリーンホテル福住
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# orkney - nearest hotel: No hotel found
# castillos - nearest hotel: A mi gente
# niemodlin - nearest hotel: Domino
# turpan - nearest hotel: Oriental
# sabang - nearest hotel: Sabang Hill
# kokopo - nearest hotel: Hotel Kokopo
# at taj - nearest hotel: No hotel found
# ouesso - nearest hotel: Auberge Nianina
# aioun - nearest hotel: فندق العيون
# saint-pierre - nearest hotel: Tropic Hotel
# yebaishou - nearest hotel: No hotel found
# castrovillari - nearest hotel: La Locanda di Alia **** AliaJazzHotel
# oroqen zizhiqi - nearest hotel: 大鮮卑酒店
# san bernardo del viento - nearest hotel: No hotel found
# ulsteinvik - nearest hotel: Quality Hotel Ulstein
# inarajan village - nearest hotel: No hotel found
# kotabumi - nearest hotel: No hotel found
# mugumu - nearest hotel: Mama hotel
# bargaal - nearest hotel: Makka Hotel Bargaal
# upington - nearest hotel: Die Eiland Holiday Ressort
# al hoceima - nearest hotel: No hotel found
# nueva esperanza - nearest hotel: Hotel Diana's
# mar del plata - nearest hotel: Nuevo Ostende
# eldorado - nearest hotel: Hotel Laçador
# xinqing - nearest hotel: No hotel found
# kalabo - nearest hotel: Golden Lodge Luxury Acomodation
# timber pines - nearest hotel: Holiday Inn Express & Suites Spring Hill
# uvira - nearest hotel: Batiment Kasangala
# santa maria - nearest hotel: Hotel Morotin
# road town - nearest hotel: No hotel found
# weyburn - nearest hotel: No hotel found
# puerto armuelles - nearest hotel: Coco del Mar
# wuchang - nearest hotel: No hotel found
# clarksville - nearest hotel: Riverview Inn
# acarau - nearest hotel: No hotel found
# kuala selangor - nearest hotel: Hotel Le-Shore
# richards bay - nearest hotel: Bon Hotel Waterfront
# hueytown - nearest hotel: Fairfield Inn Birmingham-Bessemer
# lobujya - nearest hotel: Himalaya Lodge
# inhambane - nearest hotel: Hotel de Inhambane
# newman - nearest hotel: No hotel found
# kiama - nearest hotel: Nova Kiama
# greymouth - nearest hotel: Recreation Hotel
# mont-dore - nearest hotel: Les Cases de Plum
#            City Country      Lat       Lng  Humidity             Hotel Name
# 0     papatowai      NZ -46.5619  169.4708        92         No hotel found
# 1    whitehorse      CA  60.7161 -135.0538        77  Town & Mountain Hotel
# 2         utrik      MH  11.2278  169.8474        78         No hotel found
# 3       sarikei      MY   2.1167  111.5167        52         No hotel found
# 4     boa vista      BR   2.8197  -60.6733        58     Aipana Plaza Hotel
# ..          ...     ...      ...       ...       ...                    ...
# 574   inhambane      MZ -23.8650   35.3833        56     Hotel de Inhambane
# 575      newman      US  37.3138 -121.0208        61         No hotel found
# 576       kiama      AU -34.6833  150.8667        60             Nova Kiama
# 577   greymouth      NZ -42.4667  171.2000        83       Recreation Hotel
# 578   mont-dore      NC -22.2833  166.5833        61      Les Cases de Plum
#
# [577 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
  
# Configure the map plot
# %matplotlib widget
hv.extension('bokeh')
city_name=hotel_df['City']
hotel_name=hotel_df['Hotel Name']

map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 900,
    scale = 0.7,
    color="City",
    hover_cols=["City", "Hotel Name"]
)


# Display the map
map_plot_2
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name)
